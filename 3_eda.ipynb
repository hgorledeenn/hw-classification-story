# %% [markdown]
# ### EDA of my dataset

# %%
import pandas as pd
from plotnine import *

# %%
df = pd.read_csv('data/small_w_pl.csv')

# %%
df.head()
# Out:
#                          Title                   Poet  Year  \
# 0            A Line-storm Song           Robert Frost  1913
# 1              The Weary Blues        Langston Hughes  1926
# 2  Morning in the Burned House        Margaret Atwood  1995
# 3                    On Living           Nâzim Hikmet  1994
# 4     I Could Be a Whale Shark  Aimee Nezhukumatathil  2018
#
#                                              URL  \
# 0         https://poets.org/poem/line-storm-song
# 1             https://poets.org/poem/weary-blues
# 2    https://poets.org/poem/morning-burned-house
# 3                  https://poets.org/poem/living
# 4  https://poets.org/poem/i-could-be-whale-shark
#
#                                            Poem Text  \
# 0  The line-storm clouds fly tattered and swift, ...
# 1  Droning a drowsy syncopated tune, Rocking back...
# 2  In the burned house I am eating breakfast. You...
# 3  Living is no laughing matter: you must live wi...
# ...

# %%
year_plot = (
    ggplot(df) +
    aes()
)
